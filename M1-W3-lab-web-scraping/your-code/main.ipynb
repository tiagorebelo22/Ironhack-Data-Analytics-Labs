# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended content.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit the urls below and take a look at their source code through Chrome DevTools. You'll need to identify the html tags, special class names, etc used in the html content you are expected to extract.
#
# **Resources**:
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide)
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are already imported for you. If you prefer to use additional libraries feel free to do it.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
# your code here

response = requests.get(url)
response.status_code

soup = BeautifulSoup(response.content)

print(soup)
# Out:
# <!DOCTYPE html>
# <html data-a11y-animated-images="system" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# ...

# %% [markdown]
# #### 1. Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools or clicking in 'Inspect' on any browser. Here is an example:
#
# ![title](example_1.png)
#
# 2. Use BeautifulSoup `find_all()` to extract all the html elements that contain the developer names. Hint: pass in the `attrs` parameter to specify the class.
#
# 3. Loop through the elements found and get the text for each of them.
#
# 4. While you are at it, use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names. Hint: you may also use `.get_text()` instead of `.text` and pass in the desired parameters to do some string manipulation (check the documentation).
#
# 5. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
# your code here

developers = []

developers_soup = soup.find_all("article",attrs = {"class":"Box-row d-flex"})

for element in developers_soup: 
    name = element.find_all("h1")[0].get_text(strip=True)
    # some developers do not have a secondary name
    if element.find_all("a",attrs = {"class":"Link--secondary"}) == []:
        developers.append(name)
    else:
        secondary_name = element.find_all("a",attrs = {"class":"Link--secondary"})[0].get_text(strip=True)
        developers.append(secondary_name+" ("+name+")")

print(developers)
# Out:
# ['hwchase17 (Harrison Chase)', 'merrymercy (Lianmin Zheng)', 'hrydgard (Henrik Rydgård)', 'PeerRich (Peer Richelsen)', 'Ebazhanov (Evgenii Bazhanov)', 'chenrui333 (Rui Chen)', 'oobabooga', 'MaikuB (Michael Bui)', 'fonsp (Fons van der Plas)', 'jerryjliu (Jerry Liu)', 'mattleibow (Matthew Leibowitz)', 'bluwy (Bjorn Lu)', 'sbc100 (Sam Clegg)', 'ammarahm-ed (Ammar Ahmed)', 'hughsie (Richard Hughes)', 'sunfishcode (Dan Gohman)', 'wader (Mattias Wadman)', 'lllyasviel', 'chfast (Paweł Bylica)', 'hkirat (Kirat)', 'LaurentMazare (Laurent Mazare)', 'buger (Leonid Bugaev)', 'resir014 (Resi Respati)', 'sirbrillig (Payton Swick)', 'KodrAus (Ashley Mannix)']

# %% [markdown]
# #### 1.1. Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
# your code here

response = requests.get(url)
response.status_code

soup = BeautifulSoup(response.content)

repos = []

repos_soup = soup.find_all("article",attrs = {"class":"Box-row"})

for element in repos_soup: 
    repo = element.find_all("a")[1].get_text(strip=True)
    repos.append(repo.replace(" ",""))

repos[0:10]
# Out:
# ['AIGC-Audio/AudioGPT',
#  'deep-floyd/IF',
#  'nlpxucan/WizardLM',
#  'UX-Decoder/Segment-Everything-Everywhere-All-At-Once',
#  'lamini-ai/lamini',
#  'xtekky/gpt4free',
#  'gventuri/pandas-ai',
#  'ZrrSkywalker/LLaMA-Adapter',
#  'pytube/pytube',
#  'Rapptz/discord.py']

# %% [markdown]
# #### 2. Display all the image links from Walt Disney wikipedia page.
# Hint: use `.get()` to access information inside tags. Check out the documentation.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
response = requests.get(url)
response.status_code

soup = BeautifulSoup(response.content)

imgs = []

imgs_soup = soup.find_all("img")

for element in imgs_soup: 
    img_src = element.get("src")
    if img_src.startswith("/static"):
        continue
    else:
        imgs.append("https:"+img_src)
    
imgs[0:10]
# Out:
# ['https://upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/8/8c/Extended-protection-shackle.svg/20px-Extended-protection-shackle.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Walt_Disney_Birthplace_Exterior_Hermosa_Chicago_Illinois.jpg/220px-Walt_Disney_Birthplace_Exterior_Hermosa_Chicago_Illinois.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
# ...

# %% [markdown]
# #### 2.1. List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
response = requests.get(url)
response.status_code

soup = BeautifulSoup(response.content)

lang_dict = {}

lang_soup = soup.find_all("div",attrs = {"class":"central-featured-lang"})

for element in lang_soup: 
    language = element.find_all("a")[0].strong.get_text(strip=True)
    articles = element.find_all("bdi")[0].get_text(strip=True).replace("\xa0"," ")
    lang_dict[language] = articles

lang_dict
# Out:
# {'English': '6 644 000+',
#  'Русский': '1 909 000+',
#  '日本語': '1 370 000+',
#  'Deutsch': '2 792 000+',
#  'Español': '1 854 000+',
#  'Français': '2 514 000+',
#  'Italiano': '1 806 000+',
#  '中文': '1 347 000+',
#  'فارسی': 'فارسی',
#  'Português': '1 101 000+'}

# %% [markdown]
# #### 2.2. Display the top 10 languages by number of native speakers stored in a pandas dataframe.
# Hint: After finding the correct table you want to analyse, you can use a nested **for** loop to find the elements row by row (check out the 'td' and 'tr' tags). <br>An easier way to do it is using pd.read_html(), check out documentation [here](https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.read_html.html).

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# your code here

native_speakers = pd.read_html(url,match="Languages with at least 50 million first-language speakers")[0]

native_speakers.head(10)
# Out:
#                                             Language
# 0  Mandarin Chinese (incl. Standard Chinese, but ...  \
# 1                                            Spanish
# 2                                            English
# 3            Hindi (excl. Urdu, and other languages)
# 4                                         Portuguese
# 5                                            Bengali
# 6                                            Russian
# 7                                           Japanese
# 8                      Yue Chinese (incl. Cantonese)
# 9                                         Vietnamese
#
#    Native speakers (millions) Language family        Branch
# 0                       939.0    Sino-Tibetan       Sinitic
# 1                       485.0   Indo-European       Romance
# 2                       380.0   Indo-European      Germanic
# 3                       345.0   Indo-European    Indo-Aryan
# 4                       236.0   Indo-European       Romance
# ...

# %% [markdown]
# #### 3. Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.
# Hint: If you hover over the title of the movie, you should see the director's name. Can you find where it's stored in the html?

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code here

response = requests.get(url)
response.status_code

soup = BeautifulSoup(response.content)

imdb = []

imdb_soup = soup.find_all("tbody",attrs = {"class":"lister-list"})

for element in imdb_soup[0].find_all("tr"): 
    name = element.find_all("td",attrs = {"class":"titleColumn"})[0].a.get_text(strip=True)
    release = element.find_all("td",attrs = {"class":"titleColumn"})[0].span.get_text(strip=True)
    release = release.replace("(","").replace(")","")
    director = element.find_all("td",attrs = {"class":"titleColumn"})[0].a["title"]
    director = director.split(" (dir.)")[0]
    rating = element.find_all("td",attrs = {"class":"ratingColumn imdbRating"})[0].get_text(strip=True)
    imdb.append([name,release,director,rating])
    
columns = ["movie_name","initial_release","director","stars"]
    
pd.DataFrame(imdb, columns=columns)
# Out:
#                           movie_name initial_release              director
# 0         Os Condenados de Shawshank            1994        Frank Darabont  \
# 1                         O Padrinho            1972  Francis Ford Coppola
# 2             O Cavaleiro das Trevas            2008     Christopher Nolan
# 3               O Padrinho: Parte II            1974  Francis Ford Coppola
# 4               Doze Homens em Fúria            1957          Sidney Lumet
# ..                               ...             ...                   ...
# 245               O Gigante de Ferro            1999             Brad Bird
# 246                     As Serviçais            2011           Tate Taylor
# 247                          Aladdin            1992          Ron Clements
# 248  Dersu Uzala - A Águia da Estepe            1975        Akira Kurosawa
# 249                 Danças com Lobos            1990         Kevin Costner
#
#     stars
# 0     9.2
# 1     9.2
# 2     9.0
# 3     9.0
# ...

# %% [markdown]
# #### 3.1. Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'https://www.imdb.com/list/ls009796553/'

# %%
# your code here

response = requests.get(url)
response.status_code

soup = BeautifulSoup(response.content)

imdb_random = []

imdb_random_soup = soup.find_all("div",attrs = {"class":"lister-item-content"})

for element in imdb_random_soup: 
    name = element.find_all("h3",attrs = {"class":"lister-item-header"})[0].a.get_text(strip=True)
    year = element.find_all("span",attrs = {"class":"lister-item-year"})[0].get_text(strip=True)
    if len(year.split(" ")) > 1:
        year = year.split(" ")[1]
    year = year.replace("(","").replace(")","")
    summary = element.find_all("p")[1].get_text(strip=True)
    imdb_random.append([name,year,summary])
    
columns = ["movie_name","year","summary"]
   
pd.DataFrame(imdb_random, columns=columns)
# Out:
#                         movie_name  year
# 0           Pesadelo em Elm Street  1984  \
# 1                      Despertares  1990
# 2                 Liga de Mulheres  1992
# 3         Um Bairro em Nova Iorque  1993
# 4                   Anjos em Campo  1994
# ..                             ...   ...
# 95                   Burning Palms  2010
# 96               Professora Baldas  2011
# 97  A Melhor Despedida de Solteira  2011
# 98      Chucky, o Boneco Diabólico  1988
# 99       Quem Não Chora Não... Ama  1990
#
#                                               summary
# 0   Teenager Nancy Thompson must uncover the dark ...
# 1   The victims of an encephalitis epidemic many y...
# 2   Two sisters join the first female professional...
# 3   A father becomes worried when a local gangster...
# 4   When a boy prays for a chance to have a family...
# ..                                                ...
# 95  A subversive tale that interlaces five stories...
# ...

# %% [markdown]
# ## Bonus

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'
# Out:
# Enter the city: lisbon

# %%
# your code here

response = requests.get(url)
response.status_code

response.json()

# Invalid API key
# Out:
# {'cod': 401,
#  'message': 'Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.'}

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
# your code here

response = requests.get(url)
response.status_code

soup = BeautifulSoup(response.content)


import time

books = []

for i in range(1,51):
    url = "http://books.toscrape.com/catalogue/page-"+str(i)+".html"
    response = requests.get(url)
    
    soup = BeautifulSoup(response.content)
    
    items = soup.find_all("ol") # get the listings
        
    for book in items[0].find_all("li"):
        name = book.find_all("h3")[0].a.get_text(strip=True)
        price = book.find_all("p", attrs = {"class":"price_color"})[0].get_text(strip=True)
        stock = book.find_all("p", attrs = {"class":"instock availability"})[0].get_text(strip=True)
        books.append([name,price,stock])

    time.sleep(1)

columns = ["name","price","stock"]    

pd.DataFrame(books, columns=columns)
# Out:
#                                  name   price     stock
# 0                  A Light in the ...  £51.77  In stock
# 1                  Tipping the Velvet  £53.74  In stock
# 2                          Soumission  £50.10  In stock
# 3                       Sharp Objects  £47.82  In stock
# 4        Sapiens: A Brief History ...  £54.23  In stock
# ..                                ...     ...       ...
# 995  Alice in Wonderland (Alice's ...  £55.53  In stock
# 996    Ajin: Demi-Human, Volume 1 ...  £57.06  In stock
# 997         A Spy's Devotion (The ...  £16.97  In stock
# 998           1st to Die (Women's ...  £53.98  In stock
# 999           1,000 Places to See ...  £26.08  In stock
#
# [1000 rows x 3 columns]

# %% [markdown]
# ####  Display the 100 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.
# ***Hint:*** Here the displayed number of earthquakes per page is 20, but you can easily move to the next page by looping through the desired number of pages and adding it to the end of the url.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/?view='

# This is how you will loop through each page:
number_of_pages = int(100/20)
each_page_urls = []

for n in range(1, number_of_pages+1):
    link = url+str(n)
    each_page_urls.append(link)
    
each_page_urls
# Out:
# ['https://www.emsc-csem.org/Earthquake/?view=1',
#  'https://www.emsc-csem.org/Earthquake/?view=2',
#  'https://www.emsc-csem.org/Earthquake/?view=3',
#  'https://www.emsc-csem.org/Earthquake/?view=4',
#  'https://www.emsc-csem.org/Earthquake/?view=5']

# %%
# your code here
